# %% [markdown]
# ## Import Modules

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

#sklearn
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import matthews_corrcoef

plt.style.use('fivethirtyeight')
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set_theme(style='whitegrid', font='Arial', rc={'figure.figsize':(10,5),
            'font.size':14,
            'axes.titlesize':16,
            'axes.labelsize':15,
            'xtick.labelsize': 12,
            'ytick.labelsize': 12,
            'legend.fontsize': 13},color_codes=True)

# CSV
import csv

# %%
# room number
a = 'E07'
# number of lags as input
b = '5'
# number of last timestep to predict
c = 12

# %%
# d = number of timestep to predict
for d in range(1, c+1):
    
    if d==0:
        # Timestep as string
        e = 't'
    else:
        # Timestep as string
        e = 't+'+str(d)
    
    
    # Import data
    
    # Read in data and set index

    raw_data = pd.read_csv(r"\Pre-Processing\data_E07_input_5_output_144.txt", parse_dates=True)
    data = raw_data.copy()
    data['DateTime'] = pd.to_datetime(data['DateTime'])
    data = data.set_index('DateTime')
    
    # Drop columns for Year and Second
    data = data.drop('Second_0', axis = 1)
    
    # Saving data names for later use
    data_list = list(data.columns)
    
    # Drop columns of future timestamps that should not be used as input for this model
    if d==0:
        for i in range(1,145):
            v = 't+'+str(i)
            data = data.drop(v, axis = 1)
    else:
        for i in range(d+1,145):
            v = 't+'+str(i)
            data = data.drop(v, axis = 1)

        for i in range(1, d):
            v = 't+'+str(i)
            data = data.drop(v, axis = 1)
            
    # parameter that only should be used as input
    for f in ['E07CO2', 'E07Tair', 'E07ElL', 'E07SP', 'E07W', 'E07WT']:
        
        # Create data set / dummy variables
        
        # keep only lags, one additional parameter and the timestep to predict
        if d==0:
            to_keep = [i for i in data_list[86:91]]
            to_keep.append(f)
            to_keep.append(e)
        else:
            to_keep = [i for i in data_list[86:92]]
            to_keep.append(f)
            to_keep.append(e)
            
        data_final=data[to_keep]
        data_final.columns.values
        
        # Create X and y
        X = data_final.loc[:, data_final.columns != e]
        y = data_final.loc[:, data_final.columns == e]
        
        # format y to a 1D array
        y = y.values.ravel()
        
        # format X when more than one parameter are used as input
        sc_x = StandardScaler()
        X = sc_x.fit_transform(X)
        X = pd.DataFrame(X)
        
        
        # Logistic Regression Model Fitting
        
        # Split data into training and testing sets (75 % training, 25 % testing)
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, shuffle=False, random_state=42)
        
#         # Split testing set into testing and validation sets (15 % training, 15 % validation of the whole data set --> 50/50 % of 30 %)
#         X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5, random_state=42)
        
        # Print shapes of data sets
        print('Training Data Shape:', X_train.shape)
        print('Training Labels Shape:', y_train.shape)
        print('Testing Data Shape:', X_test.shape)
        print('Testing Labels Shape:', y_test.shape)
#         print('Validation Data Shape:', X_val.shape)
#         print('Validation Labels Shape:', y_val.shape)
        
        # Create and fit model
        logreg = LogisticRegression(max_iter=1000)
        logreg.fit(X_train, y_train)
        
        # accuracy on the training set
        accuracy_train = logreg.score(X_train, y_train)
        accuracy_train_percent = round(accuracy_train*100, 3)

        # Make predictions on the test set
        y_pred = logreg.predict(X_test)
        print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
        
        # accuracy on the test set
        accuracy_test = logreg.score(X_test, y_test)
        accuracy_test_percent = round(accuracy_test*100, 3)
        print(accuracy_test)
        
#         # Make predictions on the validation set
#         y_pred_val = logreg.predict(X_val)
#         print('Accuracy of logistic regression classifier on validation set: {:.2f}'.format(logreg.score(X_val, y_val)))
        
#         # accuracy on the validation set
#         accuracy_val = logreg.score(X_val, y_val)
#         accuracy_val_percent = round(accuracy_val*100, 3)
#         print(accuracy_val)
        
        
        # Analysis of results
        
        # Confusion Matrix
        conf_matrix = confusion_matrix(y_test, y_pred)
        print(conf_matrix)
        # check if not only 0s are predicted
        count_no_occ_pred = np.count_nonzero(y_pred == 0)
        print('Number of 0 predicted: ', count_no_occ_pred)
        count_occ_pred = np.count_nonzero(y_pred == 1)
        print('Number of 1 predicted: ', count_occ_pred)
        
        # Classification Report
        print(classification_report(y_test, y_pred))
        
        # Precision
        precision = precision_score(y_test, y_pred)
        precision_percent = round((precision*100),3)
        
        # Recall
        recall = recall_score(y_test, y_pred)
        recall_percent = round((recall*100),3)

        # F1 Score
        f1 = f1_score(y_test, y_pred)
        f1_percent = round((f1*100),3)

        # Matthews Correlation Coefficient
        mcc = matthews_corrcoef(y_test, y_pred)
        
        # ROC
        logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
        fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
        plt.figure()
        plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
        plt.plot([0,1], [0,1], 'r--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver operating characteristic - '+e)
        plt.legend(loc="lower right")
        plt.savefig('Logistic_Regression_ROC_'+a+'_one_parameter_and_lags_'+f+'_forecast_'+e+'.pdf', bbox_inches='tight', dpi=100)
        plt.close()
        
        
        # Save results
        
        if d==1 and f=='E07CO2':
            # Creating csv file with results for model with all variables
            with open('Logistic_Regression_results_'+a+'_one_parameter_and_lags.csv', 'w', newline='') as file:
                writer = csv.writer(file)
                writer.writerow(['Predicted Timestep','Input', 'Accuracy - Training Set', 'Rounded Percentage', 'Accuracy - Test Set' 'Rounded Percentage', 'Precision', 'Rounded Percentage', 'Recall', 'Rounded Percentage', 'F1-Score', 'Rounded Percentage', 'Matthews Correlation Coefficient'])
                writer.writerow([e, f, accuracy_train, accuracy_train_percent, accuracy_test, accuracy_test_percent,precision, precision_percent, recall, recall_percent, f1, f1_percent, mcc])
                
        else:
            # Appending results to existing csv file
            with open('Logistic_Regression_results_'+a+'_one_parameter_and_lags.csv', 'a', newline='') as file:
                writer = csv.writer(file)
                writer.writerow([e, f, accuracy_train, accuracy_train_percent, accuracy_test, accuracy_test_percent, precision, precision_percent, recall, recall_percent, f1, f1_percent, mcc])
# Out:
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.97
# 0.9710828547990156
# [[19967   352]
#  [  353  3708]]
# Number of 0 predicted:  20320
# Number of 1 predicted:  4060
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98     20319
#          1.0       0.91      0.91      0.91      4061
#
#     accuracy                           0.97     24380
#    macro avg       0.95      0.95      0.95     24380
# weighted avg       0.97      0.97      0.97     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.97
# 0.9710828547990156
# [[19967   352]
#  [  353  3708]]
# Number of 0 predicted:  20320
# Number of 1 predicted:  4060
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98     20319
#          1.0       0.91      0.91      0.91      4061
#
#     accuracy                           0.97     24380
#    macro avg       0.95      0.95      0.95     24380
# weighted avg       0.97      0.97      0.97     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.97
# 0.9710828547990156
# [[19967   352]
#  [  353  3708]]
# Number of 0 predicted:  20320
# Number of 1 predicted:  4060
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98     20319
#          1.0       0.91      0.91      0.91      4061
#
#     accuracy                           0.97     24380
#    macro avg       0.95      0.95      0.95     24380
# weighted avg       0.97      0.97      0.97     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.97
# 0.9710828547990156
# [[19967   352]
#  [  353  3708]]
# Number of 0 predicted:  20320
# Number of 1 predicted:  4060
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98     20319
#          1.0       0.91      0.91      0.91      4061
#
#     accuracy                           0.97     24380
#    macro avg       0.95      0.95      0.95     24380
# weighted avg       0.97      0.97      0.97     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.97
# 0.9710828547990156
# [[19967   352]
#  [  353  3708]]
# Number of 0 predicted:  20320
# Number of 1 predicted:  4060
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98     20319
#          1.0       0.91      0.91      0.91      4061
#
#     accuracy                           0.97     24380
#    macro avg       0.95      0.95      0.95     24380
# weighted avg       0.97      0.97      0.97     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.97
# 0.9710828547990156
# [[19967   352]
#  [  353  3708]]
# Number of 0 predicted:  20320
# Number of 1 predicted:  4060
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98     20319
#          1.0       0.91      0.91      0.91      4061
#
#     accuracy                           0.97     24380
#    macro avg       0.95      0.95      0.95     24380
# weighted avg       0.97      0.97      0.97     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.95
# 0.9478260869565217
# [[19685   633]
#  [  639  3423]]
# Number of 0 predicted:  20324
# Number of 1 predicted:  4056
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97     20318
#          1.0       0.84      0.84      0.84      4062
#
#     accuracy                           0.95     24380
#    macro avg       0.91      0.91      0.91     24380
# weighted avg       0.95      0.95      0.95     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.95
# 0.9480721903199344
# [[19686   632]
#  [  634  3428]]
# Number of 0 predicted:  20320
# Number of 1 predicted:  4060
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97     20318
#          1.0       0.84      0.84      0.84      4062
#
#     accuracy                           0.95     24380
#    macro avg       0.91      0.91      0.91     24380
# weighted avg       0.95      0.95      0.95     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.95
# 0.9480721903199344
# [[19686   632]
#  [  634  3428]]
# Number of 0 predicted:  20320
# Number of 1 predicted:  4060
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97     20318
#          1.0       0.84      0.84      0.84      4062
#
#     accuracy                           0.95     24380
#    macro avg       0.91      0.91      0.91     24380
# weighted avg       0.95      0.95      0.95     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.95
# 0.9480721903199344
# [[19686   632]
#  [  634  3428]]
# Number of 0 predicted:  20320
# Number of 1 predicted:  4060
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97     20318
#          1.0       0.84      0.84      0.84      4062
#
#     accuracy                           0.95     24380
#    macro avg       0.91      0.91      0.91     24380
# weighted avg       0.95      0.95      0.95     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.95
# 0.9480721903199344
# [[19686   632]
#  [  634  3428]]
# Number of 0 predicted:  20320
# Number of 1 predicted:  4060
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97     20318
#          1.0       0.84      0.84      0.84      4062
#
#     accuracy                           0.95     24380
#    macro avg       0.91      0.91      0.91     24380
# weighted avg       0.95      0.95      0.95     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.95
# 0.9479081214109926
# [[19690   628]
#  [  642  3420]]
# Number of 0 predicted:  20332
# Number of 1 predicted:  4048
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97     20318
#          1.0       0.84      0.84      0.84      4062
#
#     accuracy                           0.95     24380
#    macro avg       0.91      0.91      0.91     24380
# weighted avg       0.95      0.95      0.95     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.93
# 0.9269893355209188
# [[19522   795]
#  [  985  3078]]
# Number of 0 predicted:  20507
# Number of 1 predicted:  3873
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.96      0.96     20317
#          1.0       0.79      0.76      0.78      4063
#
#     accuracy                           0.93     24380
#    macro avg       0.87      0.86      0.87     24380
# weighted avg       0.93      0.93      0.93     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.93
# 0.930188679245283
# [[19485   832]
#  [  870  3193]]
# Number of 0 predicted:  20355
# Number of 1 predicted:  4025
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.96      0.96     20317
#          1.0       0.79      0.79      0.79      4063
#
#     accuracy                           0.93     24380
#    macro avg       0.88      0.87      0.87     24380
# weighted avg       0.93      0.93      0.93     24380
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.93
# 0.9311320754716981
# [[19479   838]
#  [  841  3222]]
# Number of 0 predicted:  20320
# Number of 1 predicted:  4060
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.96      0.96     20317
#          1.0       0.79      0.79      0.79      4063
#
#     accuracy                           0.93     24380
#    macro avg       0.88      0.88      0.88     24380
# weighted avg       0.93      0.93      0.93     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.93
# 0.9311320754716981
# [[19479   838]
#  [  841  3222]]
# Number of 0 predicted:  20320
# Number of 1 predicted:  4060
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.96      0.96     20317
#          1.0       0.79      0.79      0.79      4063
#
#     accuracy                           0.93     24380
#    macro avg       0.88      0.88      0.88     24380
# weighted avg       0.93      0.93      0.93     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.93
# 0.9271123872026251
# [[19532   785]
#  [  992  3071]]
# Number of 0 predicted:  20524
# Number of 1 predicted:  3856
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.96      0.96     20317
#          1.0       0.80      0.76      0.78      4063
#
#     accuracy                           0.93     24380
#    macro avg       0.87      0.86      0.87     24380
# weighted avg       0.93      0.93      0.93     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.93
# 0.9305168170631666
# [[19484   833]
#  [  861  3202]]
# Number of 0 predicted:  20345
# Number of 1 predicted:  4035
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.96      0.96     20317
#          1.0       0.79      0.79      0.79      4063
#
#     accuracy                           0.93     24380
#    macro avg       0.88      0.87      0.87     24380
# weighted avg       0.93      0.93      0.93     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.91
# 0.9123872026251025
# [[19396   920]
#  [ 1216  2848]]
# Number of 0 predicted:  20612
# Number of 1 predicted:  3768
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.95      0.95     20316
#          1.0       0.76      0.70      0.73      4064
#
#     accuracy                           0.91     24380
#    macro avg       0.85      0.83      0.84     24380
# weighted avg       0.91      0.91      0.91     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.91
# 0.9143970467596391
# [[19368   948]
#  [ 1139  2925]]
# Number of 0 predicted:  20507
# Number of 1 predicted:  3873
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.95      0.95     20316
#          1.0       0.76      0.72      0.74      4064
#
#     accuracy                           0.91     24380
#    macro avg       0.85      0.84      0.84     24380
# weighted avg       0.91      0.91      0.91     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.91
# 0.9143560295324036
# [[19367   949]
#  [ 1139  2925]]
# Number of 0 predicted:  20506
# Number of 1 predicted:  3874
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.95      0.95     20316
#          1.0       0.76      0.72      0.74      4064
#
#     accuracy                           0.91     24380
#    macro avg       0.85      0.84      0.84     24380
# weighted avg       0.91      0.91      0.91     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.91
# 0.9143560295324036
# [[19367   949]
#  [ 1139  2925]]
# Number of 0 predicted:  20506
# Number of 1 predicted:  3874
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.95      0.95     20316
#          1.0       0.76      0.72      0.74      4064
#
#     accuracy                           0.91     24380
#    macro avg       0.85      0.84      0.84     24380
# weighted avg       0.91      0.91      0.91     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.91
# 0.9147251845775226
# [[19386   930]
#  [ 1149  2915]]
# Number of 0 predicted:  20535
# Number of 1 predicted:  3845
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.95      0.95     20316
#          1.0       0.76      0.72      0.74      4064
#
#     accuracy                           0.91     24380
#    macro avg       0.85      0.84      0.84     24380
# weighted avg       0.91      0.91      0.91     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.91
# 0.9133716160787531
# [[19388   928]
#  [ 1184  2880]]
# Number of 0 predicted:  20572
# Number of 1 predicted:  3808
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.95      0.95     20316
#          1.0       0.76      0.71      0.73      4064
#
#     accuracy                           0.91     24380
#    macro avg       0.85      0.83      0.84     24380
# weighted avg       0.91      0.91      0.91     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.9009433962264151
# [[19308  1007]
#  [ 1408  2657]]
# Number of 0 predicted:  20716
# Number of 1 predicted:  3664
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.95      0.94     20315
#          1.0       0.73      0.65      0.69      4065
#
#     accuracy                           0.90     24380
#    macro avg       0.83      0.80      0.81     24380
# weighted avg       0.90      0.90      0.90     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.9020918785890074
# [[19311  1004]
#  [ 1383  2682]]
# Number of 0 predicted:  20694
# Number of 1 predicted:  3686
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.95      0.94     20315
#          1.0       0.73      0.66      0.69      4065
#
#     accuracy                           0.90     24380
#    macro avg       0.83      0.81      0.82     24380
# weighted avg       0.90      0.90      0.90     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.9017227235438884
# [[19313  1002]
#  [ 1394  2671]]
# Number of 0 predicted:  20707
# Number of 1 predicted:  3673
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.95      0.94     20315
#          1.0       0.73      0.66      0.69      4065
#
#     accuracy                           0.90     24380
#    macro avg       0.83      0.80      0.82     24380
# weighted avg       0.90      0.90      0.90     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.9017637407711239
# [[19304  1011]
#  [ 1384  2681]]
# Number of 0 predicted:  20688
# Number of 1 predicted:  3692
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.95      0.94     20315
#          1.0       0.73      0.66      0.69      4065
#
#     accuracy                           0.90     24380
#    macro avg       0.83      0.80      0.82     24380
# weighted avg       0.90      0.90      0.90     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.9027481542247744
# [[19297  1018]
#  [ 1353  2712]]
# Number of 0 predicted:  20650
# Number of 1 predicted:  3730
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.95      0.94     20315
#          1.0       0.73      0.67      0.70      4065
#
#     accuracy                           0.90     24380
#    macro avg       0.83      0.81      0.82     24380
# weighted avg       0.90      0.90      0.90     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.904306808859721
# [[19278  1037]
#  [ 1296  2769]]
# Number of 0 predicted:  20574
# Number of 1 predicted:  3806
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.95      0.94     20315
#          1.0       0.73      0.68      0.70      4065
#
#     accuracy                           0.90     24380
#    macro avg       0.83      0.82      0.82     24380
# weighted avg       0.90      0.90      0.90     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.89
# 0.8912633305988515
# [[19267  1047]
#  [ 1604  2462]]
# Number of 0 predicted:  20871
# Number of 1 predicted:  3509
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.95      0.94     20314
#          1.0       0.70      0.61      0.65      4066
#
#     accuracy                           0.89     24380
#    macro avg       0.81      0.78      0.79     24380
# weighted avg       0.89      0.89      0.89     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.89
# 0.8940114848236259
# [[19221  1093]
#  [ 1491  2575]]
# Number of 0 predicted:  20712
# Number of 1 predicted:  3668
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.95      0.94     20314
#          1.0       0.70      0.63      0.67      4066
#
#     accuracy                           0.89     24380
#    macro avg       0.82      0.79      0.80     24380
# weighted avg       0.89      0.89      0.89     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.89
# 0.8940114848236259
# [[19221  1093]
#  [ 1491  2575]]
# Number of 0 predicted:  20712
# Number of 1 predicted:  3668
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.95      0.94     20314
#          1.0       0.70      0.63      0.67      4066
#
#     accuracy                           0.89     24380
#    macro avg       0.82      0.79      0.80     24380
# weighted avg       0.89      0.89      0.89     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.89
# 0.8940114848236259
# [[19221  1093]
#  [ 1491  2575]]
# Number of 0 predicted:  20712
# Number of 1 predicted:  3668
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.95      0.94     20314
#          1.0       0.70      0.63      0.67      4066
#
#     accuracy                           0.89     24380
#    macro avg       0.82      0.79      0.80     24380
# weighted avg       0.89      0.89      0.89     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.89
# 0.8927399507793273
# [[19235  1079]
#  [ 1536  2530]]
# Number of 0 predicted:  20771
# Number of 1 predicted:  3609
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.95      0.94     20314
#          1.0       0.70      0.62      0.66      4066
#
#     accuracy                           0.89     24380
#    macro avg       0.81      0.78      0.80     24380
# weighted avg       0.89      0.89      0.89     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.89
# 0.8933141919606234
# [[19245  1069]
#  [ 1532  2534]]
# Number of 0 predicted:  20777
# Number of 1 predicted:  3603
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.95      0.94     20314
#          1.0       0.70      0.62      0.66      4066
#
#     accuracy                           0.89     24380
#    macro avg       0.81      0.79      0.80     24380
# weighted avg       0.89      0.89      0.89     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8817473338802297
# [[19208  1105]
#  [ 1778  2289]]
# Number of 0 predicted:  20986
# Number of 1 predicted:  3394
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.95      0.93     20313
#          1.0       0.67      0.56      0.61      4067
#
#     accuracy                           0.88     24380
#    macro avg       0.79      0.75      0.77     24380
# weighted avg       0.88      0.88      0.88     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8834290401968827
# [[19201  1112]
#  [ 1730  2337]]
# Number of 0 predicted:  20931
# Number of 1 predicted:  3449
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.95      0.93     20313
#          1.0       0.68      0.57      0.62      4067
#
#     accuracy                           0.88     24380
#    macro avg       0.80      0.76      0.78     24380
# weighted avg       0.88      0.88      0.88     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8834290401968827
# [[19201  1112]
#  [ 1730  2337]]
# Number of 0 predicted:  20931
# Number of 1 predicted:  3449
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.95      0.93     20313
#          1.0       0.68      0.57      0.62      4067
#
#     accuracy                           0.88     24380
#    macro avg       0.80      0.76      0.78     24380
# weighted avg       0.88      0.88      0.88     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8840442986054142
# [[19194  1119]
#  [ 1708  2359]]
# Number of 0 predicted:  20902
# Number of 1 predicted:  3478
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.94      0.93     20313
#          1.0       0.68      0.58      0.63      4067
#
#     accuracy                           0.88     24380
#    macro avg       0.80      0.76      0.78     24380
# weighted avg       0.88      0.88      0.88     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.89
# 0.8858490566037736
# [[19160  1153]
#  [ 1630  2437]]
# Number of 0 predicted:  20790
# Number of 1 predicted:  3590
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.94      0.93     20313
#          1.0       0.68      0.60      0.64      4067
#
#     accuracy                           0.89     24380
#    macro avg       0.80      0.77      0.78     24380
# weighted avg       0.88      0.89      0.88     24380
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.89
# 0.8867104183757178
# [[19164  1149]
#  [ 1613  2454]]
# Number of 0 predicted:  20777
# Number of 1 predicted:  3603
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.94      0.93     20313
#          1.0       0.68      0.60      0.64      4067
#
#     accuracy                           0.89     24380
#    macro avg       0.80      0.77      0.79     24380
# weighted avg       0.88      0.89      0.88     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.8735849056603774
# [[19173  1139]
#  [ 1943  2125]]
# Number of 0 predicted:  21116
# Number of 1 predicted:  3264
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.94      0.93     20312
#          1.0       0.65      0.52      0.58      4068
#
#     accuracy                           0.87     24380
#    macro avg       0.78      0.73      0.75     24380
# weighted avg       0.87      0.87      0.87     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.877563576702215
# [[19133  1179]
#  [ 1806  2262]]
# Number of 0 predicted:  20939
# Number of 1 predicted:  3441
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.94      0.93     20312
#          1.0       0.66      0.56      0.60      4068
#
#     accuracy                           0.88     24380
#    macro avg       0.79      0.75      0.77     24380
# weighted avg       0.87      0.88      0.87     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8777276456111567
# [[19133  1179]
#  [ 1802  2266]]
# Number of 0 predicted:  20935
# Number of 1 predicted:  3445
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.94      0.93     20312
#          1.0       0.66      0.56      0.60      4068
#
#     accuracy                           0.88     24380
#    macro avg       0.79      0.75      0.77     24380
# weighted avg       0.87      0.88      0.87     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8783018867924528
# [[19129  1183]
#  [ 1784  2284]]
# Number of 0 predicted:  20913
# Number of 1 predicted:  3467
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.94      0.93     20312
#          1.0       0.66      0.56      0.61      4068
#
#     accuracy                           0.88     24380
#    macro avg       0.79      0.75      0.77     24380
# weighted avg       0.87      0.88      0.87     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8766611977030353
# [[19128  1184]
#  [ 1823  2245]]
# Number of 0 predicted:  20951
# Number of 1 predicted:  3429
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.94      0.93     20312
#          1.0       0.65      0.55      0.60      4068
#
#     accuracy                           0.88     24380
#    macro avg       0.78      0.75      0.76     24380
# weighted avg       0.87      0.88      0.87     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8773995077932731
# [[19158  1154]
#  [ 1835  2233]]
# Number of 0 predicted:  20993
# Number of 1 predicted:  3387
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.94      0.93     20312
#          1.0       0.66      0.55      0.60      4068
#
#     accuracy                           0.88     24380
#    macro avg       0.79      0.75      0.76     24380
# weighted avg       0.87      0.88      0.87     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.866447908121411
# [[19145  1166]
#  [ 2090  1979]]
# Number of 0 predicted:  21235
# Number of 1 predicted:  3145
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92     20311
#          1.0       0.63      0.49      0.55      4069
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.71      0.74     24380
# weighted avg       0.86      0.87      0.86     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.8678014766201805
# [[19123  1188]
#  [ 2035  2034]]
# Number of 0 predicted:  21158
# Number of 1 predicted:  3222
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92     20311
#          1.0       0.63      0.50      0.56      4069
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.72      0.74     24380
# weighted avg       0.86      0.87      0.86     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.8671862182116489
# [[19135  1176]
#  [ 2062  2007]]
# Number of 0 predicted:  21197
# Number of 1 predicted:  3183
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92     20311
#          1.0       0.63      0.49      0.55      4069
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.72      0.74     24380
# weighted avg       0.86      0.87      0.86     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.868129614438064
# [[19127  1184]
#  [ 2031  2038]]
# Number of 0 predicted:  21158
# Number of 1 predicted:  3222
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92     20311
#          1.0       0.63      0.50      0.56      4069
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.72      0.74     24380
# weighted avg       0.86      0.87      0.86     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.8700984413453651
# [[19068  1243]
#  [ 1924  2145]]
# Number of 0 predicted:  20992
# Number of 1 predicted:  3388
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.94      0.92     20311
#          1.0       0.63      0.53      0.58      4069
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.73      0.75     24380
# weighted avg       0.86      0.87      0.87     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.8709187858900739
# [[19093  1218]
#  [ 1929  2140]]
# Number of 0 predicted:  21022
# Number of 1 predicted:  3358
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.94      0.92     20311
#          1.0       0.64      0.53      0.58      4069
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.73      0.75     24380
# weighted avg       0.86      0.87      0.87     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.86
# 0.861033634126333
# [[19107  1203]
#  [ 2185  1885]]
# Number of 0 predicted:  21292
# Number of 1 predicted:  3088
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92     20310
#          1.0       0.61      0.46      0.53      4070
#
#     accuracy                           0.86     24380
#    macro avg       0.75      0.70      0.72     24380
# weighted avg       0.85      0.86      0.85     24380
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.86
# 0.8618949958982772
# [[19101  1209]
#  [ 2158  1912]]
# Number of 0 predicted:  21259
# Number of 1 predicted:  3121
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92     20310
#          1.0       0.61      0.47      0.53      4070
#
#     accuracy                           0.86     24380
#    macro avg       0.76      0.71      0.73     24380
# weighted avg       0.85      0.86      0.85     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.86
# 0.8631255127153404
# [[19085  1225]
#  [ 2112  1958]]
# Number of 0 predicted:  21197
# Number of 1 predicted:  3183
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92     20310
#          1.0       0.62      0.48      0.54      4070
#
#     accuracy                           0.86     24380
#    macro avg       0.76      0.71      0.73     24380
# weighted avg       0.85      0.86      0.86     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.86
# 0.863740771123872
# [[19081  1229]
#  [ 2093  1977]]
# Number of 0 predicted:  21174
# Number of 1 predicted:  3206
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92     20310
#          1.0       0.62      0.49      0.54      4070
#
#     accuracy                           0.86     24380
#    macro avg       0.76      0.71      0.73     24380
# weighted avg       0.85      0.86      0.86     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.86
# 0.8636997538966366
# [[19045  1265]
#  [ 2058  2012]]
# Number of 0 predicted:  21103
# Number of 1 predicted:  3277
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92     20310
#          1.0       0.61      0.49      0.55      4070
#
#     accuracy                           0.86     24380
#    macro avg       0.76      0.72      0.73     24380
# weighted avg       0.85      0.86      0.86     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.86
# 0.8623872026251025
# [[19106  1204]
#  [ 2151  1919]]
# Number of 0 predicted:  21257
# Number of 1 predicted:  3123
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92     20310
#          1.0       0.61      0.47      0.53      4070
#
#     accuracy                           0.86     24380
#    macro avg       0.76      0.71      0.73     24380
# weighted avg       0.85      0.86      0.85     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.86
# 0.8557834290401969
# [[19075  1234]
#  [ 2282  1789]]
# Number of 0 predicted:  21357
# Number of 1 predicted:  3023
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.94      0.92     20309
#          1.0       0.59      0.44      0.50      4071
#
#     accuracy                           0.86     24380
#    macro avg       0.74      0.69      0.71     24380
# weighted avg       0.84      0.86      0.85     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.85
# 0.8541427399507793
# [[19052  1257]
#  [ 2299  1772]]
# Number of 0 predicted:  21351
# Number of 1 predicted:  3029
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.94      0.91     20309
#          1.0       0.59      0.44      0.50      4071
#
#     accuracy                           0.85     24380
#    macro avg       0.74      0.69      0.71     24380
# weighted avg       0.84      0.85      0.85     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.86
# 0.8564397046759639
# [[19020  1289]
#  [ 2211  1860]]
# Number of 0 predicted:  21231
# Number of 1 predicted:  3149
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92     20309
#          1.0       0.59      0.46      0.52      4071
#
#     accuracy                           0.86     24380
#    macro avg       0.74      0.70      0.72     24380
# weighted avg       0.84      0.86      0.85     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.86
# 0.8557834290401969
# [[19022  1287]
#  [ 2229  1842]]
# Number of 0 predicted:  21251
# Number of 1 predicted:  3129
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92     20309
#          1.0       0.59      0.45      0.51      4071
#
#     accuracy                           0.86     24380
#    macro avg       0.74      0.69      0.71     24380
# weighted avg       0.84      0.86      0.85     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.86
# 0.8593929450369155
# [[18992  1317]
#  [ 2111  1960]]
# Number of 0 predicted:  21103
# Number of 1 predicted:  3277
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92     20309
#          1.0       0.60      0.48      0.53      4071
#
#     accuracy                           0.86     24380
#    macro avg       0.75      0.71      0.73     24380
# weighted avg       0.85      0.86      0.85     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.86
# 0.8568498769483183
# [[19038  1271]
#  [ 2219  1852]]
# Number of 0 predicted:  21257
# Number of 1 predicted:  3123
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92     20309
#          1.0       0.59      0.45      0.51      4071
#
#     accuracy                           0.86     24380
#    macro avg       0.74      0.70      0.72     24380
# weighted avg       0.85      0.86      0.85     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.85
# 0.8514766201804758
# [[19077  1231]
#  [ 2390  1682]]
# Number of 0 predicted:  21467
# Number of 1 predicted:  2913
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.94      0.91     20308
#          1.0       0.58      0.41      0.48      4072
#
#     accuracy                           0.85     24380
#    macro avg       0.73      0.68      0.70     24380
# weighted avg       0.84      0.85      0.84     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.85
# 0.8480721903199344
# [[19010  1298]
#  [ 2406  1666]]
# Number of 0 predicted:  21416
# Number of 1 predicted:  2964
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.94      0.91     20308
#          1.0       0.56      0.41      0.47      4072
#
#     accuracy                           0.85     24380
#    macro avg       0.72      0.67      0.69     24380
# weighted avg       0.83      0.85      0.84     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.85
# 0.8506562756357671
# [[18967  1341]
#  [ 2300  1772]]
# Number of 0 predicted:  21267
# Number of 1 predicted:  3113
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.93      0.91     20308
#          1.0       0.57      0.44      0.49      4072
#
#     accuracy                           0.85     24380
#    macro avg       0.73      0.68      0.70     24380
# weighted avg       0.84      0.85      0.84     24380
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.85
# 0.8509844134536505
# [[18965  1343]
#  [ 2290  1782]]
# Number of 0 predicted:  21255
# Number of 1 predicted:  3125
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.93      0.91     20308
#          1.0       0.57      0.44      0.50      4072
#
#     accuracy                           0.85     24380
#    macro avg       0.73      0.69      0.70     24380
# weighted avg       0.84      0.85      0.84     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.85
# 0.8545939294503692
# [[18951  1357]
#  [ 2188  1884]]
# Number of 0 predicted:  21139
# Number of 1 predicted:  3241
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.93      0.91     20308
#          1.0       0.58      0.46      0.52      4072
#
#     accuracy                           0.85     24380
#    macro avg       0.74      0.70      0.71     24380
# weighted avg       0.84      0.85      0.85     24380
#
# Training Data Shape: (73137, 7)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 7)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.85
# 0.8500410172272355
# [[18989  1319]
#  [ 2337  1735]]
# Number of 0 predicted:  21326
# Number of 1 predicted:  3054
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.94      0.91     20308
#          1.0       0.57      0.43      0.49      4072
#
#     accuracy                           0.85     24380
#    macro avg       0.73      0.68      0.70     24380
# weighted avg       0.84      0.85      0.84     24380

# %%
f
# Out:
# 'E07WT'
