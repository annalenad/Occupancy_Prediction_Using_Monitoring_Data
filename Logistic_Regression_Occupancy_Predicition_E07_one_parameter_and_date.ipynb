# %% [markdown]
# ## Import Modules

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

#sklearn
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import matthews_corrcoef


plt.style.use('fivethirtyeight')
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set_theme(style='whitegrid', font='Arial', rc={'figure.figsize':(10,5),
            'font.size':14,
            'axes.titlesize':16,
            'axes.labelsize':15,
            'xtick.labelsize': 12,
            'ytick.labelsize': 12,
            'legend.fontsize': 13},color_codes=True)

# CSV
import csv

# %%
# room number
a = 'E07'
# number of lags as input (not relevant in this case)
#b = '5'
# number of last timestep to predict
c = 12

# %%
# d = number of timestep to predict
for d in range(0, c+1):
    
    if d==0:
        # Timestep as string
        e = 't'
    else:
        # Timestep as string
        e = 't+'+str(d)
        
    
    # Import data
    
    # Read in data and set index

    raw_data = pd.read_csv("\Pre-Processing\data_E07_input_5_output_144.txt", parse_dates=True)
    data = raw_data.copy()
    data['DateTime'] = pd.to_datetime(data['DateTime'])
    data = data.set_index('DateTime')
    
    # Drop columns for Year and Second
    data = data.drop('Second_0', axis = 1)
    
    # Saving data names for later use
    data_list = list(data.columns)
    
    # Drop columns of future timestamps that should not be used as input for this model
    if d==0:
        for i in range(1,145):
            v = 't+'+str(i)
            data = data.drop(v, axis = 1)
    else:
        for i in range(d+1,145):
            v = 't+'+str(i)
            data = data.drop(v, axis = 1)

        for i in range(1, d):
            v = 't+'+str(i)
            data = data.drop(v, axis = 1)
            
            
    # parameter that only should be used as input
    if d==0:
        l = ['E07CO2', 'E07Tair', 'E07ElL', 'E07SP', 'E07W', 'E07WT', 't-1', 't-2', 't-3', 't-4','t-5']
    else:
        l = ['E07CO2', 'E07Tair', 'E07ElL', 'E07SP', 'E07W', 'E07WT', 't', 't-1', 't-2', 't-3', 't-4','t-5']
        
    for f in l:
        
        
        # Create data set / dummy variables
        
        # keep only date parameter, one additional parameter and the timestep to predict
        to_keep = [i for i in data_list[6:86]]
        to_keep.append(f)
        to_keep.append(e)
        
        data_final=data[to_keep]
        data_final.columns.values
        
        # Create X and y
        X = data_final.loc[:, data_final.columns != e]
        y = data_final.loc[:, data_final.columns == e]
        
        # format y to a 1D array
        y = y.values.ravel()
        
        # format X when more than one parameter are used as input
        sc_x = StandardScaler()
        X = sc_x.fit_transform(X)
        X = pd.DataFrame(X)
        
        
        # Logistic Regression Model Fitting
        
        # Split data into training and testing sets (75 % training, 25 % testing)
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, shuffle=False, random_state=42)
        
#         # Split testing set into testing and validation sets (15 % training, 15 % validation of the whole data set --> 50/50 % of 30 %)
#         X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5, random_state=42)
        
        # Print shapes of data sets
        print('Training Data Shape:', X_train.shape)
        print('Training Labels Shape:', y_train.shape)
        print('Testing Data Shape:', X_test.shape)
        print('Testing Labels Shape:', y_test.shape)
#         print('Validation Data Shape:', X_val.shape)
#         print('Validation Labels Shape:', y_val.shape)
        
        # Create and fit model
        logreg = LogisticRegression(max_iter=1000)
        logreg.fit(X_train, y_train)
        
        # accuracy on the training set
        accuracy_train = logreg.score(X_train, y_train)
        accuracy_train_percent = round(accuracy_train*100, 3)

        # Make predictions on the test set
        y_pred = logreg.predict(X_test)
        print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
        
        # accuracy on the test set
        accuracy_test = logreg.score(X_test, y_test)
        accuracy_test_percent = round(accuracy_test*100, 3)
        print(accuracy_test)
        
#         # Make predictions on the validation set
#         y_pred_val = logreg.predict(X_val)
#         print('Accuracy of logistic regression classifier on validation set: {:.2f}'.format(logreg.score(X_val, y_val)))
        
#         # accuracy on the validation set
#         accuracy_val = logreg.score(X_val, y_val)
#         accuracy_val_percent = round(accuracy_val*100, 3)
#         print(accuracy_val)
        
        
        # Analysis of results
        
        # Confusion Matrix
        conf_matrix = confusion_matrix(y_test, y_pred)
        print(conf_matrix)
        # check if not only 0s are predicted
        count_no_occ_pred = np.count_nonzero(y_pred == 0)
        print('Number of 0 predicted: ', count_no_occ_pred)
        count_occ_pred = np.count_nonzero(y_pred == 1)
        print('Number of 1 predicted: ', count_occ_pred)
        
        # Classification Report
        print(classification_report(y_test, y_pred))
        
        # Precision
        precision = precision_score(y_test, y_pred)
        
        # Recall
        recall = recall_score(y_test, y_pred)

        # F1 Score
        f1 = f1_score(y_test, y_pred)

        # Matthews Correlation Coefficient
        mcc = matthews_corrcoef(y_test, y_pred)
        
        # ROC
        logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
        fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
        plt.figure()
        plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
        plt.plot([0,1], [0,1], 'r--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver operating characteristic - '+e)
        plt.legend(loc="lower right")
        plt.savefig('Logistic_Regression_ROC_'+a+'_one_parameter_and_date_'+f+'_forecast_'+e+'.pdf', bbox_inches='tight', dpi=100)
        plt.close()
        
        
        # Save results
        
        if d==0 and f=='E07CO2':
            # Creating csv file with results for model with all variables
            with open('Logistic_Regression_results_'+a+'_one_parameter_and_date.csv', 'w', newline='') as file:
                writer = csv.writer(file)
                writer.writerow(['Predicted Timestep','Input', 'Accuracy - Training Set', 'Accuracy - Test Set', 'Precision', 'Recall', 'F1-Score', 'Matthews Correlation Coefficient'])
                writer.writerow([e, f, accuracy_train, accuracy_test, precision, recall,  f1, mcc ])
                
        else:
            # Appending results to existing csv file
            with open('Logistic_Regression_results_'+a+'_one_parameter_and_date.csv', 'a', newline='') as file:
                writer = csv.writer(file)
                writer.writerow([e, f, accuracy_train, accuracy_test, precision, recall,  f1, mcc ])
# Out:
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8754716981132076
# [[18606  1714]
#  [ 1322  2738]]
# Number of 0 predicted:  19928
# Number of 1 predicted:  4452
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.92      0.92     20320
#          1.0       0.62      0.67      0.64      4060
#
#     accuracy                           0.88     24380
#    macro avg       0.77      0.80      0.78     24380
# weighted avg       0.88      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.8951189499589828
# [[19024  1296]
#  [ 1261  2799]]
# Number of 0 predicted:  20285
# Number of 1 predicted:  4095
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.94      0.94     20320
#          1.0       0.68      0.69      0.69      4060
#
#     accuracy                           0.90     24380
#    macro avg       0.81      0.81      0.81     24380
# weighted avg       0.90      0.90      0.90     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.8731337161607875
# [[18427  1893]
#  [ 1200  2860]]
# Number of 0 predicted:  19627
# Number of 1 predicted:  4753
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.91      0.92     20320
#          1.0       0.60      0.70      0.65      4060
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.81      0.79     24380
# weighted avg       0.88      0.87      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.8748974569319115
# [[18592  1728]
#  [ 1322  2738]]
# Number of 0 predicted:  19914
# Number of 1 predicted:  4466
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.91      0.92     20320
#          1.0       0.61      0.67      0.64      4060
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.79      0.78     24380
# weighted avg       0.88      0.87      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.8978671041837571
# [[19048  1272]
#  [ 1218  2842]]
# Number of 0 predicted:  20266
# Number of 1 predicted:  4114
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.94      0.94     20320
#          1.0       0.69      0.70      0.70      4060
#
#     accuracy                           0.90     24380
#    macro avg       0.82      0.82      0.82     24380
# weighted avg       0.90      0.90      0.90     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.8718621821164889
# [[18435  1885]
#  [ 1239  2821]]
# Number of 0 predicted:  19674
# Number of 1 predicted:  4706
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.91      0.92     20320
#          1.0       0.60      0.69      0.64      4060
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.80      0.78     24380
# weighted avg       0.88      0.87      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.97
# 0.9711648892534864
# [[19975   345]
#  [  358  3702]]
# Number of 0 predicted:  20333
# Number of 1 predicted:  4047
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98     20320
#          1.0       0.91      0.91      0.91      4060
#
#     accuracy                           0.97     24380
#    macro avg       0.95      0.95      0.95     24380
# weighted avg       0.97      0.97      0.97     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.95
# 0.9489335520918786
# [[19719   601]
#  [  644  3416]]
# Number of 0 predicted:  20363
# Number of 1 predicted:  4017
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97     20320
#          1.0       0.85      0.84      0.85      4060
#
#     accuracy                           0.95     24380
#    macro avg       0.91      0.91      0.91     24380
# weighted avg       0.95      0.95      0.95     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.94
# 0.9353978671041837
# [[19541   779]
#  [  796  3264]]
# Number of 0 predicted:  20337
# Number of 1 predicted:  4043
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.96      0.96     20320
#          1.0       0.81      0.80      0.81      4060
#
#     accuracy                           0.94     24380
#    macro avg       0.88      0.88      0.88     24380
# weighted avg       0.94      0.94      0.94     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.92
# 0.9242821985233798
# [[19353   967]
#  [  879  3181]]
# Number of 0 predicted:  20232
# Number of 1 predicted:  4148
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.95      0.95     20320
#          1.0       0.77      0.78      0.78      4060
#
#     accuracy                           0.92     24380
#    macro avg       0.86      0.87      0.86     24380
# weighted avg       0.92      0.92      0.92     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.92
# 0.9154224774405251
# [[19256  1064]
#  [  998  3062]]
# Number of 0 predicted:  20254
# Number of 1 predicted:  4126
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95     20320
#          1.0       0.74      0.75      0.75      4060
#
#     accuracy                           0.92     24380
#    macro avg       0.85      0.85      0.85     24380
# weighted avg       0.92      0.92      0.92     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8782608695652174
# [[18601  1718]
#  [ 1250  2811]]
# Number of 0 predicted:  19851
# Number of 1 predicted:  4529
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.92      0.93     20319
#          1.0       0.62      0.69      0.65      4061
#
#     accuracy                           0.88     24380
#    macro avg       0.78      0.80      0.79     24380
# weighted avg       0.88      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.8956521739130435
# [[19002  1317]
#  [ 1227  2834]]
# Number of 0 predicted:  20229
# Number of 1 predicted:  4151
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.94      0.94     20319
#          1.0       0.68      0.70      0.69      4061
#
#     accuracy                           0.90     24380
#    macro avg       0.81      0.82      0.81     24380
# weighted avg       0.90      0.90      0.90     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8751845775225595
# [[18448  1871]
#  [ 1172  2889]]
# Number of 0 predicted:  19620
# Number of 1 predicted:  4760
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.91      0.92     20319
#          1.0       0.61      0.71      0.66      4061
#
#     accuracy                           0.88     24380
#    macro avg       0.77      0.81      0.79     24380
# weighted avg       0.88      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8772764561115669
# [[18603  1716]
#  [ 1276  2785]]
# Number of 0 predicted:  19879
# Number of 1 predicted:  4501
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.92      0.93     20319
#          1.0       0.62      0.69      0.65      4061
#
#     accuracy                           0.88     24380
#    macro avg       0.78      0.80      0.79     24380
# weighted avg       0.88      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.8994257588187039
# [[19074  1245]
#  [ 1207  2854]]
# Number of 0 predicted:  20281
# Number of 1 predicted:  4099
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.94      0.94     20319
#          1.0       0.70      0.70      0.70      4061
#
#     accuracy                           0.90     24380
#    macro avg       0.82      0.82      0.82     24380
# weighted avg       0.90      0.90      0.90     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.8728055783429041
# [[18462  1857]
#  [ 1244  2817]]
# Number of 0 predicted:  19706
# Number of 1 predicted:  4674
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.91      0.92     20319
#          1.0       0.60      0.69      0.64      4061
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.80      0.78     24380
# weighted avg       0.88      0.87      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.97
# 0.9712059064807219
# [[19974   345]
#  [  357  3704]]
# Number of 0 predicted:  20331
# Number of 1 predicted:  4049
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98     20319
#          1.0       0.91      0.91      0.91      4061
#
#     accuracy                           0.97     24380
#    macro avg       0.95      0.95      0.95     24380
# weighted avg       0.97      0.97      0.97     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.95
# 0.9488105004101722
# [[19710   609]
#  [  639  3422]]
# Number of 0 predicted:  20349
# Number of 1 predicted:  4031
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97     20319
#          1.0       0.85      0.84      0.85      4061
#
#     accuracy                           0.95     24380
#    macro avg       0.91      0.91      0.91     24380
# weighted avg       0.95      0.95      0.95     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.94
# 0.9353568498769483
# [[19512   807]
#  [  769  3292]]
# Number of 0 predicted:  20281
# Number of 1 predicted:  4099
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.96      0.96     20319
#          1.0       0.80      0.81      0.81      4061
#
#     accuracy                           0.94     24380
#    macro avg       0.88      0.89      0.88     24380
# weighted avg       0.94      0.94      0.94     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.93
# 0.9255537325676785
# [[19344   975]
#  [  840  3221]]
# Number of 0 predicted:  20184
# Number of 1 predicted:  4196
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.95      0.96     20319
#          1.0       0.77      0.79      0.78      4061
#
#     accuracy                           0.93     24380
#    macro avg       0.86      0.87      0.87     24380
# weighted avg       0.93      0.93      0.93     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.92
# 0.9176374077112387
# [[19193  1126]
#  [  882  3179]]
# Number of 0 predicted:  20075
# Number of 1 predicted:  4305
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.94      0.95     20319
#          1.0       0.74      0.78      0.76      4061
#
#     accuracy                           0.92     24380
#    macro avg       0.85      0.86      0.86     24380
# weighted avg       0.92      0.92      0.92     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.91
# 0.91214109926169
# [[19141  1178]
#  [  964  3097]]
# Number of 0 predicted:  20105
# Number of 1 predicted:  4275
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.95     20319
#          1.0       0.72      0.76      0.74      4061
#
#     accuracy                           0.91     24380
#    macro avg       0.84      0.85      0.85     24380
# weighted avg       0.91      0.91      0.91     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8812551271534045
# [[18642  1676]
#  [ 1219  2843]]
# Number of 0 predicted:  19861
# Number of 1 predicted:  4519
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.92      0.93     20318
#          1.0       0.63      0.70      0.66      4062
#
#     accuracy                           0.88     24380
#    macro avg       0.78      0.81      0.80     24380
# weighted avg       0.89      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.8954881050041017
# [[18969  1349]
#  [ 1199  2863]]
# Number of 0 predicted:  20168
# Number of 1 predicted:  4212
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.94     20318
#          1.0       0.68      0.70      0.69      4062
#
#     accuracy                           0.90     24380
#    macro avg       0.81      0.82      0.81     24380
# weighted avg       0.90      0.90      0.90     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8794093519278097
# [[18523  1795]
#  [ 1145  2917]]
# Number of 0 predicted:  19668
# Number of 1 predicted:  4712
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.91      0.93     20318
#          1.0       0.62      0.72      0.66      4062
#
#     accuracy                           0.88     24380
#    macro avg       0.78      0.81      0.80     24380
# weighted avg       0.89      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8808449548810501
# [[18667  1651]
#  [ 1254  2808]]
# Number of 0 predicted:  19921
# Number of 1 predicted:  4459
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.92      0.93     20318
#          1.0       0.63      0.69      0.66      4062
#
#     accuracy                           0.88     24380
#    macro avg       0.78      0.81      0.79     24380
# weighted avg       0.89      0.88      0.88     24380
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.9000820344544709
# [[19074  1244]
#  [ 1192  2870]]
# Number of 0 predicted:  20266
# Number of 1 predicted:  4114
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.94      0.94     20318
#          1.0       0.70      0.71      0.70      4062
#
#     accuracy                           0.90     24380
#    macro avg       0.82      0.82      0.82     24380
# weighted avg       0.90      0.90      0.90     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8779327317473339
# [[18532  1786]
#  [ 1190  2872]]
# Number of 0 predicted:  19722
# Number of 1 predicted:  4658
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.91      0.93     20318
#          1.0       0.62      0.71      0.66      4062
#
#     accuracy                           0.88     24380
#    macro avg       0.78      0.81      0.79     24380
# weighted avg       0.89      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.95
# 0.9491796554552913
# [[19701   617]
#  [  622  3440]]
# Number of 0 predicted:  20323
# Number of 1 predicted:  4057
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97     20318
#          1.0       0.85      0.85      0.85      4062
#
#     accuracy                           0.95     24380
#    macro avg       0.91      0.91      0.91     24380
# weighted avg       0.95      0.95      0.95     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.94
# 0.9360951599671862
# [[19497   821]
#  [  737  3325]]
# Number of 0 predicted:  20234
# Number of 1 predicted:  4146
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.96      0.96     20318
#          1.0       0.80      0.82      0.81      4062
#
#     accuracy                           0.94     24380
#    macro avg       0.88      0.89      0.89     24380
# weighted avg       0.94      0.94      0.94     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.93
# 0.9272764561115668
# [[19340   978]
#  [  795  3267]]
# Number of 0 predicted:  20135
# Number of 1 predicted:  4245
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.95      0.96     20318
#          1.0       0.77      0.80      0.79      4062
#
#     accuracy                           0.93     24380
#    macro avg       0.87      0.88      0.87     24380
# weighted avg       0.93      0.93      0.93     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.92
# 0.9200574241181296
# [[19202  1116]
#  [  833  3229]]
# Number of 0 predicted:  20035
# Number of 1 predicted:  4345
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.95      0.95     20318
#          1.0       0.74      0.79      0.77      4062
#
#     accuracy                           0.92     24380
#    macro avg       0.85      0.87      0.86     24380
# weighted avg       0.92      0.92      0.92     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.92
# 0.9161197703035275
# [[19125  1193]
#  [  852  3210]]
# Number of 0 predicted:  19977
# Number of 1 predicted:  4403
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.94      0.95     20318
#          1.0       0.73      0.79      0.76      4062
#
#     accuracy                           0.92     24380
#    macro avg       0.84      0.87      0.85     24380
# weighted avg       0.92      0.92      0.92     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.91
# 0.9124692370795734
# [[19104  1214]
#  [  920  3142]]
# Number of 0 predicted:  20024
# Number of 1 predicted:  4356
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.95     20318
#          1.0       0.72      0.77      0.75      4062
#
#     accuracy                           0.91     24380
#    macro avg       0.84      0.86      0.85     24380
# weighted avg       0.92      0.91      0.91     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8816242821985234
# [[18698  1619]
#  [ 1267  2796]]
# Number of 0 predicted:  19965
# Number of 1 predicted:  4415
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.92      0.93     20317
#          1.0       0.63      0.69      0.66      4063
#
#     accuracy                           0.88     24380
#    macro avg       0.78      0.80      0.79     24380
# weighted avg       0.89      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.89
# 0.8920016406890894
# [[18933  1384]
#  [ 1249  2814]]
# Number of 0 predicted:  20182
# Number of 1 predicted:  4198
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.93     20317
#          1.0       0.67      0.69      0.68      4063
#
#     accuracy                           0.89     24380
#    macro avg       0.80      0.81      0.81     24380
# weighted avg       0.89      0.89      0.89     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8781378178835111
# [[18567  1750]
#  [ 1221  2842]]
# Number of 0 predicted:  19788
# Number of 1 predicted:  4592
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.91      0.93     20317
#          1.0       0.62      0.70      0.66      4063
#
#     accuracy                           0.88     24380
#    macro avg       0.78      0.81      0.79     24380
# weighted avg       0.89      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8808039376538146
# [[18720  1597]
#  [ 1309  2754]]
# Number of 0 predicted:  20029
# Number of 1 predicted:  4351
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.92      0.93     20317
#          1.0       0.63      0.68      0.65      4063
#
#     accuracy                           0.88     24380
#    macro avg       0.78      0.80      0.79     24380
# weighted avg       0.88      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.8967186218211649
# [[19066  1251]
#  [ 1267  2796]]
# Number of 0 predicted:  20333
# Number of 1 predicted:  4047
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.94      0.94     20317
#          1.0       0.69      0.69      0.69      4063
#
#     accuracy                           0.90     24380
#    macro avg       0.81      0.81      0.81     24380
# weighted avg       0.90      0.90      0.90     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8780557834290402
# [[18584  1733]
#  [ 1240  2823]]
# Number of 0 predicted:  19824
# Number of 1 predicted:  4556
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.91      0.93     20317
#          1.0       0.62      0.69      0.66      4063
#
#     accuracy                           0.88     24380
#    macro avg       0.78      0.80      0.79     24380
# weighted avg       0.88      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.93
# 0.9339212469237079
# [[19526   791]
#  [  820  3243]]
# Number of 0 predicted:  20346
# Number of 1 predicted:  4034
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.96      0.96     20317
#          1.0       0.80      0.80      0.80      4063
#
#     accuracy                           0.93     24380
#    macro avg       0.88      0.88      0.88     24380
# weighted avg       0.93      0.93      0.93     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.92
# 0.9249794913863822
# [[19393   924]
#  [  905  3158]]
# Number of 0 predicted:  20298
# Number of 1 predicted:  4082
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.95      0.95     20317
#          1.0       0.77      0.78      0.78      4063
#
#     accuracy                           0.92     24380
#    macro avg       0.86      0.87      0.87     24380
# weighted avg       0.93      0.92      0.93     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.92
# 0.9183347005742412
# [[19266  1051]
#  [  940  3123]]
# Number of 0 predicted:  20206
# Number of 1 predicted:  4174
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95     20317
#          1.0       0.75      0.77      0.76      4063
#
#     accuracy                           0.92     24380
#    macro avg       0.85      0.86      0.85     24380
# weighted avg       0.92      0.92      0.92     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.91
# 0.914109926168991
# [[19168  1149]
#  [  945  3118]]
# Number of 0 predicted:  20113
# Number of 1 predicted:  4267
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.95     20317
#          1.0       0.73      0.77      0.75      4063
#
#     accuracy                           0.91     24380
#    macro avg       0.84      0.86      0.85     24380
# weighted avg       0.92      0.91      0.91     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.91
# 0.9115258408531584
# [[19113  1204]
#  [  953  3110]]
# Number of 0 predicted:  20066
# Number of 1 predicted:  4314
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.95     20317
#          1.0       0.72      0.77      0.74      4063
#
#     accuracy                           0.91     24380
#    macro avg       0.84      0.85      0.84     24380
# weighted avg       0.91      0.91      0.91     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.91
# 0.9089417555373257
# [[19098  1219]
#  [ 1001  3062]]
# Number of 0 predicted:  20099
# Number of 1 predicted:  4281
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.95     20317
#          1.0       0.72      0.75      0.73      4063
#
#     accuracy                           0.91     24380
#    macro avg       0.83      0.85      0.84     24380
# weighted avg       0.91      0.91      0.91     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8782198523379819
# [[18690  1626]
#  [ 1343  2721]]
# Number of 0 predicted:  20033
# Number of 1 predicted:  4347
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.92      0.93     20316
#          1.0       0.63      0.67      0.65      4064
#
#     accuracy                           0.88     24380
#    macro avg       0.78      0.79      0.79     24380
# weighted avg       0.88      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.89
# 0.8864232977850697
# [[18859  1457]
#  [ 1312  2752]]
# Number of 0 predicted:  20171
# Number of 1 predicted:  4209
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.93      0.93     20316
#          1.0       0.65      0.68      0.67      4064
#
#     accuracy                           0.89     24380
#    macro avg       0.79      0.80      0.80     24380
# weighted avg       0.89      0.89      0.89     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.874856439704676
# [[18534  1782]
#  [ 1269  2795]]
# Number of 0 predicted:  19803
# Number of 1 predicted:  4577
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.91      0.92     20316
#          1.0       0.61      0.69      0.65      4064
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.80      0.79     24380
# weighted avg       0.88      0.87      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8788351107465135
# [[18720  1596]
#  [ 1358  2706]]
# Number of 0 predicted:  20078
# Number of 1 predicted:  4302
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.92      0.93     20316
#          1.0       0.63      0.67      0.65      4064
#
#     accuracy                           0.88     24380
#    macro avg       0.78      0.79      0.79     24380
# weighted avg       0.88      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.89
# 0.8928219852337982
# [[19025  1291]
#  [ 1322  2742]]
# Number of 0 predicted:  20347
# Number of 1 predicted:  4033
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.94      0.94     20316
#          1.0       0.68      0.67      0.68      4064
#
#     accuracy                           0.89     24380
#    macro avg       0.81      0.81      0.81     24380
# weighted avg       0.89      0.89      0.89     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8755947497949139
# [[18574  1742]
#  [ 1291  2773]]
# Number of 0 predicted:  19865
# Number of 1 predicted:  4515
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.91      0.92     20316
#          1.0       0.61      0.68      0.65      4064
#
#     accuracy                           0.88     24380
#    macro avg       0.77      0.80      0.79     24380
# weighted avg       0.88      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.92
# 0.9215750615258409
# [[19395   921]
#  [  991  3073]]
# Number of 0 predicted:  20386
# Number of 1 predicted:  3994
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95     20316
#          1.0       0.77      0.76      0.76      4064
#
#     accuracy                           0.92     24380
#    macro avg       0.86      0.86      0.86     24380
# weighted avg       0.92      0.92      0.92     24380
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.92
# 0.9152173913043479
# [[19304  1012]
#  [ 1055  3009]]
# Number of 0 predicted:  20359
# Number of 1 predicted:  4021
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95     20316
#          1.0       0.75      0.74      0.74      4064
#
#     accuracy                           0.92     24380
#    macro avg       0.85      0.85      0.85     24380
# weighted avg       0.91      0.92      0.92     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.91
# 0.9110336341263331
# [[19218  1098]
#  [ 1071  2993]]
# Number of 0 predicted:  20289
# Number of 1 predicted:  4091
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95     20316
#          1.0       0.73      0.74      0.73      4064
#
#     accuracy                           0.91     24380
#    macro avg       0.84      0.84      0.84     24380
# weighted avg       0.91      0.91      0.91     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.91
# 0.9088187038556194
# [[19146  1170]
#  [ 1053  3011]]
# Number of 0 predicted:  20199
# Number of 1 predicted:  4181
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.95     20316
#          1.0       0.72      0.74      0.73      4064
#
#     accuracy                           0.91     24380
#    macro avg       0.83      0.84      0.84     24380
# weighted avg       0.91      0.91      0.91     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.91
# 0.9071369975389664
# [[19100  1216]
#  [ 1048  3016]]
# Number of 0 predicted:  20148
# Number of 1 predicted:  4232
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.94     20316
#          1.0       0.71      0.74      0.73      4064
#
#     accuracy                           0.91     24380
#    macro avg       0.83      0.84      0.84     24380
# weighted avg       0.91      0.91      0.91     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.9041427399507793
# [[19069  1247]
#  [ 1090  2974]]
# Number of 0 predicted:  20159
# Number of 1 predicted:  4221
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.94     20316
#          1.0       0.70      0.73      0.72      4064
#
#     accuracy                           0.90     24380
#    macro avg       0.83      0.84      0.83     24380
# weighted avg       0.91      0.90      0.90     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8760049220672682
# [[18644  1671]
#  [ 1352  2713]]
# Number of 0 predicted:  19996
# Number of 1 predicted:  4384
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.92      0.93     20315
#          1.0       0.62      0.67      0.64      4065
#
#     accuracy                           0.88     24380
#    macro avg       0.78      0.79      0.78     24380
# weighted avg       0.88      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8831009023789992
# [[18773  1542]
#  [ 1308  2757]]
# Number of 0 predicted:  20081
# Number of 1 predicted:  4299
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.92      0.93     20315
#          1.0       0.64      0.68      0.66      4065
#
#     accuracy                           0.88     24380
#    macro avg       0.79      0.80      0.79     24380
# weighted avg       0.89      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.874118129614438
# [[18494  1821]
#  [ 1248  2817]]
# Number of 0 predicted:  19742
# Number of 1 predicted:  4638
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.91      0.92     20315
#          1.0       0.61      0.69      0.65      4065
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.80      0.79     24380
# weighted avg       0.88      0.87      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8762510254306809
# [[18657  1658]
#  [ 1359  2706]]
# Number of 0 predicted:  20016
# Number of 1 predicted:  4364
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.92      0.93     20315
#          1.0       0.62      0.67      0.64      4065
#
#     accuracy                           0.88     24380
#    macro avg       0.78      0.79      0.78     24380
# weighted avg       0.88      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.89
# 0.8898277276456111
# [[18962  1353]
#  [ 1333  2732]]
# Number of 0 predicted:  20295
# Number of 1 predicted:  4085
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.93      0.93     20315
#          1.0       0.67      0.67      0.67      4065
#
#     accuracy                           0.89     24380
#    macro avg       0.80      0.80      0.80     24380
# weighted avg       0.89      0.89      0.89     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.8747744052502051
# [[18541  1774]
#  [ 1279  2786]]
# Number of 0 predicted:  19820
# Number of 1 predicted:  4560
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.91      0.92     20315
#          1.0       0.61      0.69      0.65      4065
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.80      0.78     24380
# weighted avg       0.88      0.87      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.91
# 0.9129614438063987
# [[19290  1025]
#  [ 1097  2968]]
# Number of 0 predicted:  20387
# Number of 1 predicted:  3993
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95     20315
#          1.0       0.74      0.73      0.74      4065
#
#     accuracy                           0.91     24380
#    macro avg       0.84      0.84      0.84     24380
# weighted avg       0.91      0.91      0.91     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.91
# 0.9081624282198524
# [[19211  1104]
#  [ 1135  2930]]
# Number of 0 predicted:  20346
# Number of 1 predicted:  4034
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.95      0.94     20315
#          1.0       0.73      0.72      0.72      4065
#
#     accuracy                           0.91     24380
#    macro avg       0.84      0.83      0.83     24380
# weighted avg       0.91      0.91      0.91     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.91
# 0.9068498769483183
# [[19151  1164]
#  [ 1107  2958]]
# Number of 0 predicted:  20258
# Number of 1 predicted:  4122
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.94     20315
#          1.0       0.72      0.73      0.72      4065
#
#     accuracy                           0.91     24380
#    macro avg       0.83      0.84      0.83     24380
# weighted avg       0.91      0.91      0.91     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.9048400328137818
# [[19071  1244]
#  [ 1076  2989]]
# Number of 0 predicted:  20147
# Number of 1 predicted:  4233
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.94     20315
#          1.0       0.71      0.74      0.72      4065
#
#     accuracy                           0.90     24380
#    macro avg       0.83      0.84      0.83     24380
# weighted avg       0.91      0.90      0.91     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.9037325676784249
# [[19028  1287]
#  [ 1060  3005]]
# Number of 0 predicted:  20088
# Number of 1 predicted:  4292
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.94     20315
#          1.0       0.70      0.74      0.72      4065
#
#     accuracy                           0.90     24380
#    macro avg       0.82      0.84      0.83     24380
# weighted avg       0.91      0.90      0.90     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.901394585726005
# [[19006  1309]
#  [ 1095  2970]]
# Number of 0 predicted:  20101
# Number of 1 predicted:  4279
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.94     20315
#          1.0       0.69      0.73      0.71      4065
#
#     accuracy                           0.90     24380
#    macro avg       0.82      0.83      0.83     24380
# weighted avg       0.90      0.90      0.90     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8759228876127974
# [[18572  1742]
#  [ 1283  2783]]
# Number of 0 predicted:  19855
# Number of 1 predicted:  4525
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.91      0.92     20314
#          1.0       0.62      0.68      0.65      4066
#
#     accuracy                           0.88     24380
#    macro avg       0.78      0.80      0.79     24380
# weighted avg       0.88      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8815422477440525
# [[18705  1609]
#  [ 1279  2787]]
# Number of 0 predicted:  19984
# Number of 1 predicted:  4396
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.92      0.93     20314
#          1.0       0.63      0.69      0.66      4066
#
#     accuracy                           0.88     24380
#    macro avg       0.78      0.80      0.79     24380
# weighted avg       0.89      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.873174733388023
# [[18421  1893]
#  [ 1199  2867]]
# Number of 0 predicted:  19620
# Number of 1 predicted:  4760
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.91      0.92     20314
#          1.0       0.60      0.71      0.65      4066
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.81      0.79     24380
# weighted avg       0.88      0.87      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.8741591468416735
# [[18583  1731]
#  [ 1337  2729]]
# Number of 0 predicted:  19920
# Number of 1 predicted:  4460
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.91      0.92     20314
#          1.0       0.61      0.67      0.64      4066
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.79      0.78     24380
# weighted avg       0.88      0.87      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.89
# 0.8882690730106645
# [[18916  1398]
#  [ 1326  2740]]
# Number of 0 predicted:  20242
# Number of 1 predicted:  4138
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.93      0.93     20314
#          1.0       0.66      0.67      0.67      4066
#
#     accuracy                           0.89     24380
#    macro avg       0.80      0.80      0.80     24380
# weighted avg       0.89      0.89      0.89     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.874856439704676
# [[18484  1830]
#  [ 1221  2845]]
# Number of 0 predicted:  19705
# Number of 1 predicted:  4675
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.91      0.92     20314
#          1.0       0.61      0.70      0.65      4066
#
# ...
# Number of 1 predicted:  4245
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.94     20310
#          1.0       0.69      0.72      0.70      4070
#
#     accuracy                           0.90     24380
#    macro avg       0.81      0.83      0.82     24380
# weighted avg       0.90      0.90      0.90     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.8954881050041017
# [[18956  1354]
#  [ 1194  2876]]
# Number of 0 predicted:  20150
# Number of 1 predicted:  4230
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.94     20310
#          1.0       0.68      0.71      0.69      4070
#
#     accuracy                           0.90     24380
#    macro avg       0.81      0.82      0.82     24380
# weighted avg       0.90      0.90      0.90     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.8746513535684988
# [[18607  1702]
#  [ 1354  2717]]
# Number of 0 predicted:  19961
# Number of 1 predicted:  4419
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.92      0.92     20309
#          1.0       0.61      0.67      0.64      4071
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.79      0.78     24380
# weighted avg       0.88      0.87      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.87850697292863
# [[18654  1655]
#  [ 1307  2764]]
# Number of 0 predicted:  19961
# Number of 1 predicted:  4419
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.92      0.93     20309
#          1.0       0.63      0.68      0.65      4071
#
#     accuracy                           0.88     24380
#    macro avg       0.78      0.80      0.79     24380
# weighted avg       0.88      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.8741591468416735
# [[18489  1820]
#  [ 1248  2823]]
# Number of 0 predicted:  19737
# Number of 1 predicted:  4643
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.91      0.92     20309
#          1.0       0.61      0.69      0.65      4071
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.80      0.79     24380
# weighted avg       0.88      0.87      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8753076292042657
# [[18639  1670]
#  [ 1370  2701]]
# Number of 0 predicted:  20009
# Number of 1 predicted:  4371
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.92      0.92     20309
#          1.0       0.62      0.66      0.64      4071
#
#     accuracy                           0.88     24380
#    macro avg       0.77      0.79      0.78     24380
# weighted avg       0.88      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8826907301066448
# [[18833  1476]
#  [ 1384  2687]]
# Number of 0 predicted:  20217
# Number of 1 predicted:  4163
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.93      0.93     20309
#          1.0       0.65      0.66      0.65      4071
#
#     accuracy                           0.88     24380
#    macro avg       0.79      0.79      0.79     24380
# weighted avg       0.88      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.8739950779327318
# [[18559  1750]
#  [ 1322  2749]]
# Number of 0 predicted:  19881
# Number of 1 predicted:  4499
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.91      0.92     20309
#          1.0       0.61      0.68      0.64      4071
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.79      0.78     24380
# weighted avg       0.88      0.87      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.8985233798195242
# [[18986  1323]
#  [ 1151  2920]]
# Number of 0 predicted:  20137
# Number of 1 predicted:  4243
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.94     20309
#          1.0       0.69      0.72      0.70      4071
#
#     accuracy                           0.90     24380
#    macro avg       0.82      0.83      0.82     24380
# weighted avg       0.90      0.90      0.90     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.8961033634126333
# [[18966  1343]
#  [ 1190  2881]]
# Number of 0 predicted:  20156
# Number of 1 predicted:  4224
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.94     20309
#          1.0       0.68      0.71      0.69      4071
#
#     accuracy                           0.90     24380
#    macro avg       0.81      0.82      0.82     24380
# weighted avg       0.90      0.90      0.90     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.8958982772764561
# [[18960  1349]
#  [ 1189  2882]]
# Number of 0 predicted:  20149
# Number of 1 predicted:  4231
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.94     20309
#          1.0       0.68      0.71      0.69      4071
#
#     accuracy                           0.90     24380
#    macro avg       0.81      0.82      0.82     24380
# weighted avg       0.90      0.90      0.90     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.8965135356849877
# [[18964  1345]
#  [ 1178  2893]]
# Number of 0 predicted:  20142
# Number of 1 predicted:  4238
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.94     20309
#          1.0       0.68      0.71      0.70      4071
#
#     accuracy                           0.90     24380
#    macro avg       0.81      0.82      0.82     24380
# weighted avg       0.90      0.90      0.90     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.90
# 0.8957342083675144
# [[18933  1376]
#  [ 1166  2905]]
# Number of 0 predicted:  20099
# Number of 1 predicted:  4281
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.94     20309
#          1.0       0.68      0.71      0.70      4071
#
#     accuracy                           0.90     24380
#    macro avg       0.81      0.82      0.82     24380
# weighted avg       0.90      0.90      0.90     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.89
# 0.893929450369155
# [[18920  1389]
#  [ 1197  2874]]
# Number of 0 predicted:  20117
# Number of 1 predicted:  4263
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.94     20309
#          1.0       0.67      0.71      0.69      4071
#
#     accuracy                           0.89     24380
#    macro avg       0.81      0.82      0.81     24380
# weighted avg       0.90      0.89      0.89     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.8749384741591468
# [[18557  1751]
#  [ 1298  2774]]
# Number of 0 predicted:  19855
# Number of 1 predicted:  4525
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.91      0.92     20308
#          1.0       0.61      0.68      0.65      4072
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.80      0.78     24380
# weighted avg       0.88      0.87      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.877850697292863
# [[18598  1710]
#  [ 1268  2804]]
# Number of 0 predicted:  19866
# Number of 1 predicted:  4514
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.92      0.93     20308
#          1.0       0.62      0.69      0.65      4072
#
#     accuracy                           0.88     24380
#    macro avg       0.78      0.80      0.79     24380
# weighted avg       0.88      0.88      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.8729286300246103
# [[18414  1894]
#  [ 1204  2868]]
# Number of 0 predicted:  19618
# Number of 1 predicted:  4762
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.91      0.92     20308
#          1.0       0.60      0.70      0.65      4072
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.81      0.79     24380
# weighted avg       0.88      0.87      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.874200164068909
# [[18587  1721]
#  [ 1346  2726]]
# Number of 0 predicted:  19933
# Number of 1 predicted:  4447
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.92      0.92     20308
#          1.0       0.61      0.67      0.64      4072
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.79      0.78     24380
# weighted avg       0.88      0.87      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.88
# 0.8814602132895816
# [[18811  1497]
#  [ 1393  2679]]
# Number of 0 predicted:  20204
# Number of 1 predicted:  4176
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.93      0.93     20308
#          1.0       0.64      0.66      0.65      4072
#
#     accuracy                           0.88     24380
#    macro avg       0.79      0.79      0.79     24380
# weighted avg       0.88      0.88      0.88     24380
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.87
# 0.8730106644790813
# [[18498  1810]
#  [ 1286  2786]]
# Number of 0 predicted:  19784
# Number of 1 predicted:  4596
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.91      0.92     20308
#          1.0       0.61      0.68      0.64      4072
#
#     accuracy                           0.87     24380
#    macro avg       0.77      0.80      0.78     24380
# weighted avg       0.88      0.87      0.88     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.89
# 0.8947087776866284
# [[18890  1418]
#  [ 1149  2923]]
# Number of 0 predicted:  20039
# Number of 1 predicted:  4341
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.94     20308
#          1.0       0.67      0.72      0.69      4072
#
#     accuracy                           0.89     24380
#    macro avg       0.81      0.82      0.82     24380
# weighted avg       0.90      0.89      0.90     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.89
# 0.8937243642329779
# [[18887  1421]
#  [ 1170  2902]]
# Number of 0 predicted:  20057
# Number of 1 predicted:  4323
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.94     20308
#          1.0       0.67      0.71      0.69      4072
#
#     accuracy                           0.89     24380
#    macro avg       0.81      0.82      0.81     24380
# weighted avg       0.90      0.89      0.89     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.89
# 0.8947497949138639
# [[18897  1411]
#  [ 1155  2917]]
# Number of 0 predicted:  20052
# Number of 1 predicted:  4328
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.94     20308
#          1.0       0.67      0.72      0.69      4072
#
#     accuracy                           0.89     24380
#    macro avg       0.81      0.82      0.82     24380
# weighted avg       0.90      0.89      0.90     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.89
# 0.8947908121410992
# [[18879  1429]
#  [ 1136  2936]]
# Number of 0 predicted:  20015
# Number of 1 predicted:  4365
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.94     20308
#          1.0       0.67      0.72      0.70      4072
#
#     accuracy                           0.89     24380
#    macro avg       0.81      0.83      0.82     24380
# weighted avg       0.90      0.89      0.90     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.89
# 0.8929450369155045
# [[18850  1458]
#  [ 1152  2920]]
# Number of 0 predicted:  20002
# Number of 1 predicted:  4378
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.94     20308
#          1.0       0.67      0.72      0.69      4072
#
#     accuracy                           0.89     24380
#    macro avg       0.80      0.82      0.81     24380
# weighted avg       0.90      0.89      0.89     24380
#
# Training Data Shape: (73137, 81)
# Training Labels Shape: (73137,)
# Testing Data Shape: (24380, 81)
# Testing Labels Shape: (24380,)
# Accuracy of logistic regression classifier on test set: 0.89
# 0.8910172272354389
# [[18847  1461]
#  [ 1196  2876]]
# Number of 0 predicted:  20043
# Number of 1 predicted:  4337
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.93     20308
#          1.0       0.66      0.71      0.68      4072
#
#     accuracy                           0.89     24380
#    macro avg       0.80      0.82      0.81     24380
# weighted avg       0.89      0.89      0.89     24380
